# %% [markdown]
# # Deployment

# %%
from IPython.display import Image
#from IPython.core.display import HTML 
from IPython.display import SVG

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Interpretability of Convnet

# %% [markdown]
# http://cs231n.github.io/understanding-cnn/
#
# https://towardsdatascience.com/visual-interpretability-for-convolutional-neural-networks-2453856210ce
#
# https://heartbeat.fritz.ai/model-interpretability-and-visualization-looking-inside-the-neural-network-black-box-79f45f2cb771
#
#
# https://uoguelph-mlrg.github.io/Iceland-Tutorials/slides/Devinder_Interpretability_workshop_uiceland_slides.pdf
#
# http://www.shallowmind.co/jekyll/pixyll/2017/12/30/tree-regularization/
#
# https://distill.pub/2018/building-blocks/
#
# https://www.analyticsvidhya.com/blog/2019/05/understanding-visualizing-neural-networks/
#
# https://machinelearningmastery.com/visualize-deep-learning-neural-network-model-keras/

# %% [markdown]
# # Reports

# %%
img="binder.png"
Image(filename= img, width=500, height=500)

# %% [markdown]
# # Data Products

# %% [markdown]
# Proposed app with 4 views

# %% [markdown]
# I. Open Image
# - Import Dicom image in for your case

# %% [markdown]
# II. Detect and Select
# - Flags potential nodules and Assigns a probability

# %% [markdown]
# III. Annotate and Segment
# - AI locates and segments ROI's
# - Radiologist can add additional information

# %% [markdown]
# IV. Export and Report
# - Generate Standard Report

# %% [markdown]
# - interface frontend at http://localhost:8080
#
#
# Keep clicking until you reach *.dcm. Then view a series...

# %%
#svg= '../data/coc.svg'
#SVG(svg)
